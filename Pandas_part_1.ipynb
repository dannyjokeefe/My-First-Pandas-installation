# %%
pip install pandas
# this will install pandas library in python
# however its already installed in colab

# %%
# import library
import pandas

# %%
pandas.__version__
# Out:
# '2.2.2'

# %%
import pandas as pd
#pd is shortname for pandas

# %%
pd.Flags
# Out:
# pandas.core.flags.Flags

# %%
pd.__version__
# Out:
# '2.2.2'

# %% [markdown]
# #whenever you need to use a feature of pandas library, you will start code with pd.

# %% [markdown]
# #how to manually create dataframe

# %%
data = {
    "calories": [420, 380, 390],
    "duration": [50, 40,45]
}
#This is a dictionary with list

# %%
print (type(data))
# Out:
# <class 'dict'>

# %% [markdown]
# converting dictionary to dataframe

# %%
pd.DataFrame(data)
#create a dataframe from a dictionary
# Out:
#    calories  duration
# 0       420        50
# 1       380        40
# 2       390        45
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['calories'].plot(kind='hist', bins=20, title='calories')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['duration'].plot(kind='hist', bins=20, title='duration')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_2.plot(kind='scatter', x='calories', y='duration', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
# ...

# %%
from google.colab import files
uploaded = files.upload()
#import file from pc to colab
# Out:
#      <input type="file" id="files-7f3f40b8-29f8-41d6-9b8f-7dcfb111d971" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7f3f40b8-29f8-41d6-9b8f-7dcfb111d971">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# # if you get xlsx extension, dont worry, there is a solution

# %% [markdown]
# run below code if you have xlsx file extension

# %%
df = pd.read_excel("student.xlsx")

# %%
df = pd.read_excel("student.xlsx")
# df = pd.read_csv("student.csv") if csv file
# import file to notebook
# save as df (DataFrame)

# %%
df
#df stands for DataFrame and df will import dataset and save it as df in my notebook
# Out:
#     id         name  class  mark  gender
# 0    1     John Deo   Four    75  female
# 1    2     Max Ruin  Three    85    male
# 2    3       Arnold  Three    55    male
# 3    4   Krish Star   Four    60  female
# 4    5    John Mike   Four    60  female
# 5    6    Alex John   Four    55    male
# 6    7  My John Rob  Fifth    78    male
# 7    8       Asruid   Five    85    male
# 8    9      Tes Qry    Six    78     NaN
# 9   10     Big John   Four    55  female
# 10  11       Ronald    Six    89  female
# 11  12        Recky    Six    94  female
# 12  13          Kty  Seven    88  female
# 13  14         Bigy  Seven    88  female
# 14  15     Tade Row    NaN    88    male
# 15  16        Gimmy   Four    88    male
# 16  17        Tumyu    Six    54    male
# 17  18        Honny   Five    75    male
# 18  19        Tinny   Nine    18    male
# 19  20       Jackly   Nine    65  female
# 20  21   Babby John   Four    69  female
# 21  22       Reggid  Seven    55  female
# ...

# %% [markdown]
# ## inspecting dataset

# %%
df.head()
#returns first 5 rows
# Out:
#    id        name  class  mark  gender
# 0   1    John Deo   Four    75  female
# 1   2    Max Ruin  Three    85    male
# 2   3      Arnold  Three    55    male
# 3   4  Krish Star   Four    60  female
# 4   5   John Mike   Four    60  female

# %%
df.tail()
#returns last 5 rows of data
# Out:
#     id         name  class  mark  gender
# 30  31  Marry Toeey   Four    88    male
# 31  32    Binn Rott  Seven    90  female
# 32  33    Kenn Rein    Six    96  female
# 33  34     Gain Toe  Seven    69    male
# 34  35   Rows Noump    Six    88  female

# %%
df.head(3)
#first 3 rows returned
# Out:
#    id      name  class  mark  gender
# 0   1  John Deo   Four    75  female
# 1   2  Max Ruin  Three    85    male
# 2   3    Arnold  Three    55    male

# %%
df.tail(7)
# last 7 of dataset
# Out:
#     id         name  class  mark  gender
# 28  29  Tess Played  Seven    55    male
# 29  30    Reppy Red    Six    79  female
# 30  31  Marry Toeey   Four    88    male
# 31  32    Binn Rott  Seven    90  female
# 32  33    Kenn Rein    Six    96  female
# 33  34     Gain Toe  Seven    69    male
# 34  35   Rows Noump    Six    88  female

# %%
df.sample()
# 1 sample by default
# Out:
#    id       name class  mark gender
# 5   6  Alex John  Four    55   male

# %%
df.sample(4)
# 4 random samples
# Out:
#     id       name  class  mark  gender
# 21  22     Reggid  Seven    55  female
# 23  24  Tiddy Now  Seven    78    male
# 11  12      Recky    Six    94  female
# 31  32  Binn Rott  Seven    90  female

# %%
df.shape
# how many rows and columns are there?
# there are 35 rows and 5 columns
# Out:
# (35, 5)

# %%
df.info()
# will return al info of the dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      35 non-null     int64
#  1   name    34 non-null     object
#  2   class   34 non-null     object
#  3   mark    35 non-null     int64
#  4   gender  33 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 1.5+ KB

# %% [markdown]
# Pay attention to
#
#
# *  non-null count
# *  data type
#
# if non-null count is different than total entries, there are missing values
# <p> name, gender and class have a missing value

# %%
df.columns
# name of the columns
# Out:
# Index(['id', 'name', 'class', 'mark', 'gender'], dtype='object')

# %%
df.describe()
# info about numeric columns
# average mark of student is 74.65 (mean)
# Out:
#               id       mark
# count  35.000000  35.000000
# mean   18.000000  74.657143
# std    10.246951  16.401117
# min     1.000000  18.000000
# 25%     9.500000  62.500000
# 50%    18.000000  79.000000
# 75%    26.500000  88.000000
# max    35.000000  96.000000

# %% [markdown]
# *   std = standard deviation
# *   25% of the students have a mark of 62.5 or less
# *   50% of students have a mark of 79 or less
# *   this is useful to identify outlier

# %% [markdown]
# # if std is very close or greater than mean there are outliers

# %%
len(df)
# returns number of rows
# Out:
# 35

# %%
df.size
#number of rows * number of columns
# 35 * 5
# Out:
# 175

# %%
df.dtypes
# Out:
# id         int64
# name      object
# class     object
# mark       int64
# gender    object
# dtype: object

# %%
df.isnull().sum()
#tells me how many values are missing per column
# Out:
# id        0
# name      1
# class     1
# mark      0
# gender    2
# dtype: int64

# %%
df.duplicated().sum()
# sum will count number of true values
# Out:
# np.int64(0)

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# dtype: bool

# %%
df.isnull()
# Out:
#        id   name  class   mark  gender
# 0   False  False  False  False   False
# 1   False  False  False  False   False
# 2   False  False  False  False   False
# 3   False  False  False  False   False
# 4   False  False  False  False   False
# 5   False  False  False  False   False
# 6   False  False  False  False   False
# 7   False  False  False  False   False
# 8   False  False  False  False    True
# 9   False  False  False  False   False
# 10  False  False  False  False   False
# 11  False  False  False  False   False
# 12  False  False  False  False   False
# 13  False  False  False  False   False
# 14  False  False   True  False   False
# 15  False  False  False  False   False
# 16  False  False  False  False   False
# 17  False  False  False  False   False
# 18  False  False  False  False   False
# 19  False  False  False  False   False
# 20  False  False  False  False   False
# 21  False  False  False  False   False
# 22  False  False  False  False   False
# ...

# %% [markdown]
# #subsetting dataset

# %%
df.head()
# Out:
#    id        name  class  mark  gender
# 0   1    John Deo   Four    75  female
# 1   2    Max Ruin  Three    85    male
# 2   3      Arnold  Three    55    male
# 3   4  Krish Star   Four    60  female
# 4   5   John Mike   Four    60  female

# %%
# return names only
df["name"]
# Out:
# 0        John Deo
# 1        Max Ruin
# 2          Arnold
# 3      Krish Star
# 4       John Mike
# 5       Alex John
# 6     My John Rob
# 7          Asruid
# 8         Tes Qry
# 9        Big John
# 10         Ronald
# 11          Recky
# 12            Kty
# 13           Bigy
# 14       Tade Row
# 15          Gimmy
# 16          Tumyu
# 17          Honny
# 18          Tinny
# 19         Jackly
# 20     Babby John
# 21         Reggid
# 22          Herod
# 23      Tiddy Now
# 24       Giff Tow
# 25         Crelea
# 26            NaN
# 27      Rojj Base
# 28    Tess Played
# 29      Reppy Red
# 30    Marry Toeey
# 31      Binn Rott
# 32      Kenn Rein
# 33       Gain Toe
# 34     Rows Noump
# Name: name, dtype: object

# %%
df.mark
# this is dot notation, but it may not work if column name is the same as a keyword in python.
# Out:
# 0     75
# 1     85
# 2     55
# 3     60
# 4     60
# 5     55
# 6     78
# 7     85
# 8     78
# 9     55
# 10    89
# 11    94
# 12    88
# 13    88
# 14    88
# 15    88
# 16    54
# 17    75
# 18    18
# 19    65
# 20    69
# 21    55
# 22    79
# 23    78
# 24    88
# 25    79
# 26    81
# 27    86
# 28    55
# 29    79
# 30    88
# 31    90
# 32    96
# 33    69
# 34    88
# Name: mark, dtype: int64

# %%
df.class
#error becuase class is reversed keyword
# Out:
#   File "<ipython-input-43-251322824050>", line 1
#     df.class
#        ^
# SyntaxError: invalid syntax

# %%
df["class"]
# Out:
# 0      Four
# 1     Three
# 2     Three
# 3      Four
# 4      Four
# 5      Four
# 6     Fifth
# 7      Five
# 8       Six
# 9      Four
# 10      Six
# 11      Six
# 12    Seven
# 13    Seven
# 14      NaN
# 15     Four
# 16      Six
# 17     Five
# 18     Nine
# 19     Nine
# 20     Four
# 21    Seven
# 22    Eight
# 23    Seven
# 24    Seven
# 25    Seven
# 26    Three
# 27    Seven
# 28    Seven
# 29      Six
# 30     Four
# 31    Seven
# 32      Six
# 33    Seven
# 34      Six
# Name: class, dtype: object

# %%
df["class"].head()
# Out:
# 0     Four
# 1    Three
# 2    Three
# 3     Four
# 4     Four
# Name: class, dtype: object

# %%
df["mark"].mean()
# calculate average mark
# Out:
# np.float64(74.65714285714286)

# %%
df["mark"].head().median()
# mediam mark for first 5 students in this class
# Out:
# 60.0

# %% [markdown]
# #return names and classes of first 5 students

# %%
df[["class", "name"]].head()
# you can only write 1 column in slicing method
# if you need to return more than 1 column, include them in a list
# first [] used for slicing
# second []used for list of column names
# Out:
#    class        name
# 0   Four    John Deo
# 1  Three    Max Ruin
# 2  Three      Arnold
# 3   Four  Krish Star
# 4   Four   John Mike

# %%
df[["name", "gender", "mark"]].sample(3)
# Out:
#          name gender  mark
# 7      Asruid   male    85
# 33   Gain Toe   male    69
# 5   Alex John   male    55

# %% [markdown]
# ## loc and iloc

# %%
df.loc[0:4, "name"]
#[rows to return, column names]
# Out:
# 0      John Deo
# 1      Max Ruin
# 2        Arnold
# 3    Krish Star
# 4     John Mike
# Name: name, dtype: object

# %%
df.iloc[0:5, 1]
# 1 is the index of the name column
# Out:
# 0      John Deo
# 1      Max Ruin
# 2        Arnold
# 3    Krish Star
# 4     John Mike
# Name: name, dtype: object

# %%
df.iloc[0:5, 1:4]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-3556749fc6de> in <cell line: 0>()
# ----> 1 df.iloc[0:5, 1:4]
#
# NameError: name 'df' is not defined

# %%
import pandas

# %%
import pandas as pd

# %%
df.iloc[0:5, 1:4]
# Out:
#          name  class  mark
# 0    John Deo   Four    75
# 1    Max Ruin  Three    85
# 2      Arnold  Three    55
# 3  Krish Star   Four    60
# 4   John Mike   Four    60

# %%
df.head()
# Out:
#    id        name  class  mark  gender
# 0   1    John Deo   Four    75  female
# 1   2    Max Ruin  Three    85    male
# 2   3      Arnold  Three    55    male
# 3   4  Krish Star   Four    60  female
# 4   5   John Mike   Four    60  female

# %% [markdown]
# 1. return name and class of first 3 students

# %%
df [["name", "class"]].head(3)
# other solution - df[['name', 'class']][:3]
# Out:
#        name  class
# 0  John Deo   Four
# 1  Max Ruin  Three
# 2    Arnold  Three

# %% [markdown]
# 2. return the average mark for all students

# %%
df['mark']. mean()
# other solution - df['mark'].mean()
# Out:
# np.float64(74.65714285714286)

# %% [markdown]
# 3. return 3 sample class and gender of the students

# %%
df.iloc[0:3, 0:5].sample(3)
# other solution - df[['class','gender'2]].sample(3)
# Out:
#    id      name  class  mark  gender
# 0   1  John Deo   Four    75  female
# 1   2  Max Ruin  Three    85    male
# 2   3    Arnold  Three    55    male

# %% [markdown]
# 4. return first 5 rows

# %%
df.iloc[5:1]
# Out:
# Empty DataFrame
# Columns: [id, name, class, mark, gender]
# Index: []

# %%
df[["id", "name", "class", "mark", "gender" ]].head(5)
# Out:
#    id        name  class  mark  gender
# 0   1    John Deo   Four    75  female
# 1   2    Max Ruin  Three    85    male
# 2   3      Arnold  Three    55    male
# 3   4  Krish Star   Four    60  female
# 4   5   John Mike   Four    60  female

# %%
df.loc[0:4, "id":"gender"]
# df.loc[:4]
# Out:
#    id        name  class  mark  gender
# 0   1    John Deo   Four    75  female
# 1   2    Max Ruin  Three    85    male
# 2   3      Arnold  Three    55    male
# 3   4  Krish Star   Four    60  female
# 4   5   John Mike   Four    60  female

# %%
df[:5]
# Out:
#    id        name  class  mark  gender
# 0   1    John Deo   Four    75  female
# 1   2    Max Ruin  Three    85    male
# 2   3      Arnold  Three    55    male
# 3   4  Krish Star   Four    60  female
# 4   5   John Mike   Four    60  female

# %%
df. head ()
# Out:
#    id        name  class  mark  gender
# 0   1    John Deo   Four    75  female
# 1   2    Max Ruin  Three    85    male
# 2   3      Arnold  Three    55    male
# 3   4  Krish Star   Four    60  female
# 4   5   John Mike   Four    60  female

# %% [markdown]
# <p>loc{rows:columns] if you ignore columns it will return all columns in dataset
# <p>iloc{rows:columns] if you only write row numbers it will return all columns
# <p> if you dont specify start of the range it will start from index 0

# %%
# return index 2  and index 27
df.loc[[2,27]]
# Out:
#     id       name  class  mark  gender
# 2    3     Arnold  Three    55    male
# 27  28  Rojj Base  Seven    86  female

# %% [markdown]
# df [] is used for slicing
# if you write condition inside you will be filtering data

# %%
# return male students
df[df["gender"]== "male"]
# Out:
#     id         name  class  mark gender
# 1    2     Max Ruin  Three    85   male
# 2    3       Arnold  Three    55   male
# 5    6    Alex John   Four    55   male
# 6    7  My John Rob  Fifth    78   male
# 7    8       Asruid   Five    85   male
# 14  15     Tade Row    NaN    88   male
# 15  16        Gimmy   Four    88   male
# 16  17        Tumyu    Six    54   male
# 17  18        Honny   Five    75   male
# 18  19        Tinny   Nine    18   male
# 22  23        Herod  Eight    79   male
# 23  24    Tiddy Now  Seven    78   male
# 24  25     Giff Tow  Seven    88   male
# 25  26       Crelea  Seven    79   male
# 28  29  Tess Played  Seven    55   male
# 30  31  Marry Toeey   Four    88   male
# 33  34     Gain Toe  Seven    69   male

# %% [markdown]
# write code to return student class of six?

# %%
df[df["class"] == "Six"]
# Out:
#     id        name class  mark  gender
# 8    9     Tes Qry   Six    78     NaN
# 10  11      Ronald   Six    89  female
# 11  12       Recky   Six    94  female
# 16  17       Tumyu   Six    54    male
# 29  30   Reppy Red   Six    79  female
# 32  33   Kenn Rein   Six    96  female
# 34  35  Rows Noump   Six    88  female

# %% [markdown]
# retuen students with mark less than 52

# %%
df[df["mark"]<=52]
# Out:
#     id   name class  mark gender
# 18  19  Tinny  Nine    18   male

# %%
df.loc[df["mark"]< 52]
# Out:
#     id   name class  mark gender
# 18  19  Tinny  Nine    18   male

# %% [markdown]
# return female students with theit mark greater than 80

# %%
df[ (df["gender"] == "female") & (df["mark"]>80) ]
# Out:
#     id        name  class  mark  gender
# 10  11      Ronald    Six    89  female
# 11  12       Recky    Six    94  female
# 12  13         Kty  Seven    88  female
# 13  14        Bigy  Seven    88  female
# 27  28   Rojj Base  Seven    86  female
# 31  32   Binn Rott  Seven    90  female
# 32  33   Kenn Rein    Six    96  female
# 34  35  Rows Noump    Six    88  female

# %%
df.loc[ (df["gender"]=="female") & (df["mark"]>80) ]
# Out:
#     id        name  class  mark  gender
# 10  11      Ronald    Six    89  female
# 11  12       Recky    Six    94  female
# 12  13         Kty  Seven    88  female
# 13  14        Bigy  Seven    88  female
# 27  28   Rojj Base  Seven    86  female
# 31  32   Binn Rott  Seven    90  female
# 32  33   Kenn Rein    Six    96  female
# 34  35  Rows Noump    Six    88  female

# %%
df[ (df["gender"]=="female") & (df["mark"]>80) ].head()
# Out:
#     id       name  class  mark  gender
# 10  11     Ronald    Six    89  female
# 11  12      Recky    Six    94  female
# 12  13        Kty  Seven    88  female
# 13  14       Bigy  Seven    88  female
# 27  28  Rojj Base  Seven    86  female

# %%
df.loc[ (df["gender"]=="female") & (df["mark"]>80), ["name","gender"] ].head()
# Out:
#          name  gender
# 10     Ronald  female
# 11      Recky  female
# 12        Kty  female
# 13       Bigy  female
# 27  Rojj Base  female

# %%
# female students mark greater than 80 and class seven
df.loc[ (df["gender"]=="female") & (df["mark"]>80) & (df["class"]=="Seven"),["name","gender"] ]
# Out:
#          name  gender
# 12        Kty  female
# 13       Bigy  female
# 27  Rojj Base  female
# 31  Binn Rott  female

# %%
df[ (df["gender"] == "male") | (df["class"] == "Five") ]
# Out:
#     id         name  class  mark gender
# 1    2     Max Ruin  Three    85   male
# 2    3       Arnold  Three    55   male
# 5    6    Alex John   Four    55   male
# 6    7  My John Rob  Fifth    78   male
# 7    8       Asruid   Five    85   male
# 14  15     Tade Row    NaN    88   male
# 15  16        Gimmy   Four    88   male
# 16  17        Tumyu    Six    54   male
# 17  18        Honny   Five    75   male
# 18  19        Tinny   Nine    18   male
# 22  23        Herod  Eight    79   male
# 23  24    Tiddy Now  Seven    78   male
# 24  25     Giff Tow  Seven    88   male
# 25  26       Crelea  Seven    79   male
# 28  29  Tess Played  Seven    55   male
# 30  31  Marry Toeey   Four    88   male
# 33  34     Gain Toe  Seven    69   male

# %%
#average mark across all students
df["mark"]. mean()
# Out:
# np.float64(74.65714285714286)

# %%
#average mark of male and female students
df.loc[df["gender"]=="female", "mark"].mean()
df.loc[df["gender"]=="male", "mark"].mean()

#df[(df["gender"] == "male")]["mark"].mean()
#df[(df["gender"] == "female")]["mark"].mean()
# Out:
# np.float64(71.58823529411765)

# %%
# find min and max mark
df["mark"].min(), df["mark"].max()
# Out:
# (18, 96)

# %%
df[ (df["mark"] == df["mark"].min()) | (df["mark"] == df["mark"].max()) ]
# Out:
#     id       name class  mark  gender
# 18  19      Tinny  Nine    18    male
# 32  33  Kenn Rein   Six    96  female

# %%
df[(df["class"]=="Five")]["mark"].mean()
# Out:
# np.float64(80.0)

# %%
df[(df["gender"]=="male") & (df["class"]=="Six")]["mark"].mean()
# Out:
# np.float64(54.0)

# %%
df.loc[df["name"].str.contains("John", na=False)]
# str will convert pandas series to a string object
#na=False will skip any missing values
# Out:
#     id         name  class  mark  gender
# 0    1     John Deo   Four    75  female
# 4    5    John Mike   Four    60  female
# 5    6    Alex John   Four    55    male
# 6    7  My John Rob  Fifth    78    male
# 9   10     Big John   Four    55  female
# 20  21   Babby John   Four    69  female

# %% [markdown]
# #Sorting Results

# %%
df.sort_values(by="mark")
# sort results by mark column
# Out:
#     id         name  class  mark  gender
# 18  19        Tinny   Nine    18    male
# 16  17        Tumyu    Six    54    male
# 2    3       Arnold  Three    55    male
# 5    6    Alex John   Four    55    male
# 28  29  Tess Played  Seven    55    male
# 21  22       Reggid  Seven    55  female
# 9   10     Big John   Four    55  female
# 4    5    John Mike   Four    60  female
# 3    4   Krish Star   Four    60  female
# 19  20       Jackly   Nine    65  female
# 20  21   Babby John   Four    69  female
# 33  34     Gain Toe  Seven    69    male
# 0    1     John Deo   Four    75  female
# 17  18        Honny   Five    75    male
# 8    9      Tes Qry    Six    78     NaN
# 23  24    Tiddy Now  Seven    78    male
# 6    7  My John Rob  Fifth    78    male
# 22  23        Herod  Eight    79    male
# 29  30    Reppy Red    Six    79  female
# 25  26       Crelea  Seven    79    male
# 26  27          NaN  Three    81     NaN
# 1    2     Max Ruin  Three    85    male
# ...

# %%
df.sort_values(by="name")
# Out:
#     id         name  class  mark  gender
# 5    6    Alex John   Four    55    male
# 2    3       Arnold  Three    55    male
# 7    8       Asruid   Five    85    male
# 20  21   Babby John   Four    69  female
# 9   10     Big John   Four    55  female
# 13  14         Bigy  Seven    88  female
# 31  32    Binn Rott  Seven    90  female
# 25  26       Crelea  Seven    79    male
# 33  34     Gain Toe  Seven    69    male
# 24  25     Giff Tow  Seven    88    male
# 15  16        Gimmy   Four    88    male
# 22  23        Herod  Eight    79    male
# 17  18        Honny   Five    75    male
# 19  20       Jackly   Nine    65  female
# 0    1     John Deo   Four    75  female
# 4    5    John Mike   Four    60  female
# 32  33    Kenn Rein    Six    96  female
# 3    4   Krish Star   Four    60  female
# 12  13          Kty  Seven    88  female
# 30  31  Marry Toeey   Four    88    male
# 1    2     Max Ruin  Three    85    male
# 6    7  My John Rob  Fifth    78    male
# ...

# %%
df.loc[df["mark"]>50].sort_values(by="mark")
# Out:
#     id         name  class  mark  gender
# 16  17        Tumyu    Six    54    male
# 2    3       Arnold  Three    55    male
# 9   10     Big John   Four    55  female
# 5    6    Alex John   Four    55    male
# 21  22       Reggid  Seven    55  female
# 28  29  Tess Played  Seven    55    male
# 3    4   Krish Star   Four    60  female
# 4    5    John Mike   Four    60  female
# 19  20       Jackly   Nine    65  female
# 20  21   Babby John   Four    69  female
# 33  34     Gain Toe  Seven    69    male
# 17  18        Honny   Five    75    male
# 0    1     John Deo   Four    75  female
# 8    9      Tes Qry    Six    78     NaN
# 6    7  My John Rob  Fifth    78    male
# 23  24    Tiddy Now  Seven    78    male
# 29  30    Reppy Red    Six    79  female
# 25  26       Crelea  Seven    79    male
# 22  23        Herod  Eight    79    male
# 26  27          NaN  Three    81     NaN
# 1    2     Max Ruin  Three    85    male
# 7    8       Asruid   Five    85    male
# ...

# %%
df.loc[:, "name"].sort_values()
# you can ignore by arguement if there is only one column in the output
# Out:
# 5       Alex John
# 2          Arnold
# 7          Asruid
# 20     Babby John
# 9        Big John
# 13           Bigy
# 31      Binn Rott
# 25         Crelea
# 33       Gain Toe
# 24       Giff Tow
# 15          Gimmy
# 22          Herod
# 17          Honny
# 19         Jackly
# 0        John Deo
# 4       John Mike
# 32      Kenn Rein
# 3      Krish Star
# 12            Kty
# 30    Marry Toeey
# 1        Max Ruin
# 6     My John Rob
# 11          Recky
# 21         Reggid
# 29      Reppy Red
# 27      Rojj Base
# 10         Ronald
# 34     Rows Noump
# 14       Tade Row
# 8         Tes Qry
# 28    Tess Played
# 23      Tiddy Now
# 18          Tinny
# 16          Tumyu
# 26            NaN
# Name: name, dtype: object

# %%
df.loc[1:10, ["name", "class"]].sort_values(by="class")
# Out:
#            name  class
# 6   My John Rob  Fifth
# 7        Asruid   Five
# 3    Krish Star   Four
# 4     John Mike   Four
# 5     Alex John   Four
# 9      Big John   Four
# 8       Tes Qry    Six
# 10       Ronald    Six
# 1      Max Ruin  Three
# 2        Arnold  Three

# %% [markdown]
# # you will use ascending = false if you want to sort descending

# %%
df.sort_values(by="mark", ascending=False).head()
# Out:
#     id         name  class  mark  gender
# 32  33    Kenn Rein    Six    96  female
# 11  12        Recky    Six    94  female
# 31  32    Binn Rott  Seven    90  female
# 10  11       Ronald    Six    89  female
# 30  31  Marry Toeey   Four    88    male

# %%
df.loc[:, :].sort_values(by="gender", ascending=False).head()
# Out:
#     id      name  class  mark gender
# 17  18     Honny   Five    75   male
# 22  23     Herod  Eight    79   male
# 24  25  Giff Tow  Seven    88   male
# 25  26    Crelea  Seven    79   male
# 18  19     Tinny   Nine    18   male

# %% [markdown]
# # Value Counts
# <p1> return frequency of each value in a coulmn

# %%
df["gender"].value_counts()
# how many males and how many females?
# Out:
# gender
# male      17
# female    16
# Name: count, dtype: int64

# %%
df["class"].value_counts()
# number of students in each class
# Out:
# class
# Seven    10
# Four      8
# Six       7
# Three     3
# Nine      2
# Five      2
# Fifth     1
# Eight     1
# Name: count, dtype: int64
